# %%
import numpy as np
import matplotlib.pyplot as plt

import pytoolsMH as ptMH

# %%
xs = np.linspace(0,3*np.pi)
plt.plot(xs,np.sin(xs))

# %%
xs = np.linspace(0,3*np.pi)
plt.plot(xs,np.sin(xs))
ptMH.plotting.add_scalebar(plt.gca(),loc=9,fmtstrx='$%.1f\pi$',sizex=1)
plt.box(False)

# %%
# ?ptMH.plotting.add_scalebar
# Out:
# Signature: ptMH.plotting.add_scalebar(ax, sizex=None, sizey=None, hidex=True, hidey=True, fmtstrx='%.1f', fmtstry='%.1f', **kwargs)
# Docstring:
# Add scalebars to axes
#
# Adds a set of scale bars to *ax*, matching the size to the ticks of the plot
# and optionally hiding the x and y axes
#
# Args:
#     - ax : the axis to attach ticks to
#     - sizex,sizey:
#         None (Default): set size of scale bars to spacing between ticks
#         numeric value: sets size of x and y bars in data units
#     - hidex,hidey : if True, hide x-axis and y-axis of parent
#     - fmtstrx,fmtstry : label format string to use to generate labels.
#            e.g. xlabel is fmtstrx % sizex.  defaults: '%.1f'
#     - **kwargs : additional arguments passed to AnchoredScaleBars, e.g. loc
#
# Notes:
#     loc: string or integer (see mpl.offsetbox.AnchoredOffsetbox)
#         The valid location codes are::
#
#         'upper right'  : 1,
#         'upper left'   : 2,
#         'lower left'   : 3,
# ...

# %%
# ?ptMH.plotting.AnchoredScaleBar
